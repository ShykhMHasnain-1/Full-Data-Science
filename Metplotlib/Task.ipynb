# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Updated Student DataSet.csv")
data
# Out:
#      Unnamed: 0        roll_no           name  exam1  exam2  final_exam class  \
# 0             0  SMIT/DSAI/001    David Iqbal     20     16          35  DSAI
# 1             1  SMIT/DSAI/002    Ahmed Ahmed     13      7          40  DSAI
# 2             2  SMIT/DSAI/003     John Zahid     13     24          47  DSAI
# 3             3  SMIT/DSAI/004    David Brown      0     15          24  DSAI
# 4             4  SMIT/DSAI/005    Fatima Khan     20      8           6  DSAI
# ..          ...            ...            ...    ...    ...         ...   ...
# 495         495   SMIT/MAW/096     Sara Zahid      8     10          45   MAW
# 496         496   SMIT/MAW/097     Ayesha Ali     14      3          31   MAW
# 497         497   SMIT/MAW/098  Michael Brown      2     20          50   MAW
# 498         498   SMIT/MAW/099     Sara Malik     24      6          16   MAW
# 499         499   SMIT/MAW/100       Noor Ali      9     11          44   MAW
#
#      obtain  total   per grades
# ...

# %%
data['class'] = data['roll_no'].str.split('/').str[1]

# %%
class_cat = data.groupby("class")
for cat in class_cat:
    print(class_cat["grades"].value_counts())
# Out:
# class  grades
# DM     B         33
#        C         31
#        F         30
#        A          6
# DSAI   C         35
#        B         30
#        F         30
#        A          5
# GD     C         34
#        B         33
#        F         30
#        A          3
# MAW    C         45
#        F         27
#        B         26
#        A          2
# UIUX   C         35
#        F         33
#        B         27
#        A          5
# Name: count, dtype: int64
# ********************
# class  grades
# DM     B         33
#        C         31
#        F         30
#        A          6
# DSAI   C         35
#        B         30
#        F         30
#        A          5
# GD     C         34
#        B         33
#        F         30
#        A          3
# MAW    C         45
#        F         27
#        B         26
#        A          2
# UIUX   C         35
#        F         33
#        B         27
#        A          5
# Name: count, dtype: int64
# ...
