# %%
import matplotlib.pyplot as plt
#print(matplotlib.__version__)

# %%
x = [0,1,2,3,4,5]
y = [0,1,4,9,16,25]

# %%
plt.plot(x,y)
plt.title("X vs Y")
plt.text(0,16,"Data")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()
